# %% [markdown]
# **Problem 1A-Single Year HDI Exploration(2022)**

# %% [markdown]
# **Import Libraries & Load DataSet**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load full dataset
df = pd.read_csv("/content/drive/MyDrive/Copy of Human_Development_Index_Dataset (1).csv", encoding='latin1')

# %% [markdown]
# **1) Extract Latest Year(2022)**

# %% [markdown]
# **Identify unique years**

# %%
df['year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %% [markdown]
# **Filter dataset for 2022**

# %%
hdi_2022_df = df[df['year'] == 2022].copy()

# %% [markdown]
# **Data Exploration**

# %% [markdown]
# Display first 10 rows

# %%
hdi_2022_df.head(10)
# Out:
#      Unnamed: 0 iso3              country  year    hdi  life_expectancy  \
# 32           33  AFG          Afghanistan  2022  0.462           62.879
# 65           66  ALB              Albania  2022  0.789           76.833
# 98           99  DZA              Algeria  2022  0.745           77.129
# 131         132  AND              Andorra  2022  0.884           83.552
# 164         165  AGO               Angola  2022  0.591           61.929
# 197         198  ATG  Antigua and Barbuda  2022  0.826           79.236
# 230         231  ARG            Argentina  2022  0.849           76.064
# 263         264  ARM              Armenia  2022  0.786           73.372
# 296         297  AUS            Australia  2022  0.946           83.579
# 329         330  AUT              Austria  2022  0.926           82.412
#
#      pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 32      41.128771  0.332443  0.534145        66.213  ...               0.622
# ...

# %% [markdown]
# Number of rows and columns

# %%
hdi_2022_df.shape
# Out:
# (206, 30)

# %% [markdown]
# Column names and data types

# %%
hdi_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206 entries, 32 to 6797
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 206 non-null    int64
#  1   iso3                       206 non-null    object
#  2   country                    206 non-null    object
#  3   year                       206 non-null    int64
#  4   hdi                        204 non-null    float64
#  5   life_expectancy            206 non-null    float64
#  6   pop_millions               206 non-null    float64
#  7   hdi_f                      193 non-null    float64
#  8   hdi_m                      193 non-null    float64
#  9   life_expec_f               206 non-null    float64
#  10  life_expec_m               206 non-null    float64
#  11  expec_yr_school            205 non-null    float64
#  12  expec_yr_school_f          205 non-null    float64
# ...

# %% [markdown]
# **Missing Values & Data Cleaning**

# %% [markdown]
# Check missing values

# %%
hdi_2022_df.isna().sum()
# Out:
# Unnamed: 0                    0
# iso3                          0
# country                       0
# year                          0
# hdi                           2
# life_expectancy               0
# pop_millions                  0
# hdi_f                        13
# hdi_m                        13
# life_expec_f                  0
# life_expec_m                  0
# expec_yr_school               1
# expec_yr_school_f             1
# expec_yr_school_m             1
# mean_yr_school                2
# mean_yr_school_f              2
# mean_yr_school_m              2
# gross_inc_percap              2
# gross_inc_percap_f           13
# gross_inc_percap_m           13
# gender_development           13
# gender_inequality            29
# secondary_education_f_%      17
# secondary_education_m_%      17
# seats_in_parliament_f_%       2
# seats_in_parliament_m_%       2
# labour_participation_f_%     12
# labour_participation_m_%     12
# co2_emission_tons             2
# ...

# %% [markdown]
# **Cleanin Steps**

# %%
hdi_2022_df.dtypes
# we can see, all the data in numeric columns are numerical values
# Out:
# Unnamed: 0                     int64
# iso3                          object
# country                       object
# year                           int64
# hdi                          float64
# life_expectancy              float64
# pop_millions                 float64
# hdi_f                        float64
# hdi_m                        float64
# life_expec_f                 float64
# life_expec_m                 float64
# expec_yr_school              float64
# expec_yr_school_f            float64
# expec_yr_school_m            float64
# mean_yr_school               float64
# mean_yr_school_f             float64
# mean_yr_school_m             float64
# gross_inc_percap             float64
# gross_inc_percap_f           float64
# gross_inc_percap_m           float64
# gender_development           float64
# gender_inequality            float64
# secondary_education_f_%      float64
# secondary_education_m_%      float64
# seats_in_parliament_f_%      float64
# ...

# %% [markdown]
# **inconsistent or misspelled country names**

# %%
df['country'].str.strip().value_counts()
# Out:
# country
# Afghanistan                        33
# Albania                            33
# Algeria                            33
# Andorra                            33
# Angola                             33
#                                    ..
# Europe and Central Asia            33
# Latin America and the Caribbean    33
# South Asia                         33
# Sub-Saharan Africa                 33
# World                              33
# Name: count, Length: 206, dtype: int64

# %% [markdown]
# **Checking duplicate rows**

# %%
hdi_2022_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **special characters representing missing data(ex: "-")**

# %%
special_symbols = ["-"]
hdi_2022_df.isin(special_symbols).sum()
hdi_2022_df = hdi_2022_df.replace(special_symbols, pd.NA)

# %% [markdown]
# **Remove duplicates**

# %%
hdi_2022_df.drop_duplicates()
# Out:
#       Unnamed: 0       iso3                          country  year    hdi  \
# 32            33        AFG                      Afghanistan  2022  0.462
# 65            66        ALB                          Albania  2022  0.789
# 98            99        DZA                          Algeria  2022  0.745
# 131          132        AND                          Andorra  2022  0.884
# 164          165        AGO                           Angola  2022  0.591
# ...          ...        ...                              ...   ...    ...
# 6665        6666    ZZG.ECA          Europe and Central Asia  2022  0.802
# 6698        6699    ZZH.LAC  Latin America and the Caribbean  2022  0.763
# 6731        6732     ZZI.SA                       South Asia  2022  0.641
# 6764        6765    ZZJ.SSA               Sub-Saharan Africa  2022  0.549
# 6797        6798  ZZK.WORLD                            World  2022  0.739
#
#       life_expectancy  pop_millions     hdi_f     hdi_m  life_expec_f  ...  \
# ...

# %% [markdown]
# **handle missing valies(drop or impute:justify your choice)**

# %%
null_percentage = hdi_2022_df.isnull().sum() / hdi_2022_df.shape[0] * 100
null_columns_fill = null_percentage[null_percentage > 10].index

hdi_2022_df.fillna(hdi_2022_df[null_columns_fill].mean(), inplace=True)

null_columns_drop = null_percentage[null_percentage <= 10].index
hdi_2022_df.dropna(subset=null_columns_drop, inplace=True)

print(hdi_2022_df.isnull().sum())
# Out:
# Unnamed: 0                   0
# iso3                         0
# country                      0
# year                         0
# hdi                          0
# life_expectancy              0
# pop_millions                 0
# hdi_f                        0
# hdi_m                        0
# life_expec_f                 0
# life_expec_m                 0
# expec_yr_school              0
# expec_yr_school_f            0
# expec_yr_school_m            0
# mean_yr_school               0
# mean_yr_school_f             0
# mean_yr_school_m             0
# gross_inc_percap             0
# gross_inc_percap_f           0
# gross_inc_percap_m           0
# gender_development           0
# gender_inequality            0
# secondary_education_f_%      0
# secondary_education_m_%      0
# seats_in_parliament_f_%      0
# seats_in_parliament_m_%      0
# labour_participation_f_%     0
# labour_participation_m_%     0
# co2_emission_tons            0
# mat_footprint_percap_tons    0
# ...

# %% [markdown]
# **Basic Statistics(HDI-2022)**

# %%
mean_hdi = hdi_2022_df['hdi'].mean()
median_hdi = hdi_2022_df['hdi'].median()
std_hdi = hdi_2022_df['hdi'].std()

print(f"Mean HDI for 2022: {mean_hdi}")
print(f"Median HDI for 2022: {median_hdi}")
print(f"Standard Deviation of HDI for 2022: {std_hdi}")
# Out:
# Mean HDI for 2022: 0.7268333333333336
# Median HDI for 2022: 0.7415
# Standard Deviation of HDI for 2022: 0.15219828657299067

# %% [markdown]
# **Highest HDI Country**

# %%
hdi_2022_df.loc[hdi_2022_df['hdi'].idxmax(),['country','hdi']]
# Out:
# country    Switzerland
# hdi              0.967
# Name: 5609, dtype: object

# %% [markdown]
# **Lowest HDI Country**

# %%
hdi_2022_df.loc[hdi_2022_df['hdi'].idxmin(),['country','hdi']]
# Out:
# country    Somalia
# hdi           0.38
# Name: 5345, dtype: object

# %% [markdown]
# **Filtering and Sorting**

# %% [markdown]
# **Filter countries with HDI {"hdi"} greater than 0.800**

# %%
countries_hdi_greater_eight = hdi_2022_df[(hdi_2022_df["hdi"] > 0.8)]
countries_hdi_greater_eight[["hdi","country","year"]]
# Out:
#         hdi                      country  year
# 230   0.849                    Argentina  2022
# 296   0.946                    Australia  2022
# 329   0.926                      Austria  2022
# 395   0.820                      Bahamas  2022
# 428   0.888                      Bahrain  2022
# ...     ...                          ...   ...
# 6137  0.940               United Kingdom  2022
# 6170  0.927                United States  2022
# 6203  0.830                      Uruguay  2022
# 6467  0.902  Very high human development  2022
# 6665  0.802      Europe and Central Asia  2022
#
# [64 rows x 3 columns]

# %% [markdown]
# **Sort this filtered dataset by Gross National Income (GNI) per Capita {"gross inc percap"} in
# descending order.**

# %%
countries_by_gni_desc = countries_hdi_greater_eight.sort_values(by="gross_inc_percap", ascending=False)
countries_by_gni_desc[["hdi","country","year","gross_inc_percap"]].head(10)
# Out:
#         hdi               country  year  gross_inc_percap
# 4718  0.875                 Qatar  2022       95944.37754
# 5213  0.949             Singapore  2022       88761.14559
# 2705  0.950               Ireland  2022       87467.51391
# 3398  0.927            Luxembourg  2022       78554.23640
# 6104  0.937  United Arab Emirates  2022       74103.71494
# 5609  0.967           Switzerland  2022       69432.78669
# 4322  0.966                Norway  2022       69189.76165
# 6170  0.927         United States  2022       65564.93798
# 1550  0.952               Denmark  2022       62018.95694
# 824   0.823     Brunei Darussalam  2022       59245.63485

# %% [markdown]
# **Display the top 10 countries**

# %%
countries_by_gni_desc.head(10)
# Out:
#       Unnamed: 0 iso3               country  year    hdi  life_expectancy  \
# 4718        4719  QAT                 Qatar  2022  0.875           81.559
# 5213        5214  SGP             Singapore  2022  0.949           84.133
# 2705        2706  IRL               Ireland  2022  0.950           82.716
# 3398        3399  LUX            Luxembourg  2022  0.927           82.591
# 6104        6105  ARE  United Arab Emirates  2022  0.937           79.196
# 5609        5610  CHE           Switzerland  2022  0.967           84.255
# 4322        4323  NOR                Norway  2022  0.966           83.393
# 6170        6171  USA         United States  2022  0.927           78.203
# 1550        1551  DNK               Denmark  2022  0.952           81.882
# 824          825  BRN     Brunei Darussalam  2022  0.823           74.551
#
#       pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# ...

# %% [markdown]
# **Adding HDI Category Column**

# %%
def hdi_category(data):
  if data < 0.550:
    return "Low"
  elif data >= 0.550 and data <= 0.699:
    return "Medium"
  elif data >= 0.700 and data <= 0.799:
    return "High"
  else:
    return "Very"

# %% [markdown]
# **Verification**

# %%
hdi_2022_df['hdi_category']= hdi_2022_df['hdi'].apply(hdi_category)

# %% [markdown]
# **Save Final Dataset**

# %%
hdi_2022_df.to_csv("HDI_2022.csv", index=False)

# %% [markdown]
#  **Problem- 1B- HDI Visualization and Trend Analysis (2020– 2022)**

# %% [markdown]
# **1. Data Extraction and Saving:**

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/drive/MyDrive/Copy of Human_Development_Index_Dataset (1).csv", encoding='latin1')

# Filter required years
df_filtered = df[df['year'].isin([2020, 2021, 2022])].copy()

# Save filtered dataset
df_filtered.to_csv("HDI_problem1B.csv", index=False)

df_filtered.head()
# Out:
#     Unnamed: 0 iso3      country  year    hdi  life_expectancy  pop_millions  \
# 30          31  AFG  Afghanistan  2020  0.488           62.575     38.972231
# 31          32  AFG  Afghanistan  2021  0.473           61.982     40.099462
# 32          33  AFG  Afghanistan  2022  0.462           62.879     41.128771
# 63          64  ALB      Albania  2020  0.784           76.989      2.866849
# 64          65  ALB      Albania  2021  0.785           76.463      2.854710
#
#        hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 30  0.381373  0.548741        65.432  ...               0.695
# 31  0.379129  0.528559        65.279  ...               0.717
# 32  0.332443  0.534145        66.213  ...               0.622
# 63  0.775404  0.793220        79.676  ...               0.978
# 64  0.777866  0.792942        79.173  ...               0.981
#
#     gender_inequality  secondary_education_f_%  secondary_education_m_%  \
# ...

# %% [markdown]
# **2. Data Cleaning decisions and implementation**

# %%
null_count_hdi = df_filtered["hdi"].isnull().sum()
null_count_country = df_filtered["country"].isnull().sum()
null_count_year = df_filtered["year"].isnull().sum()

print(f"Number of null values in 'hdi': {null_count_hdi}")
print(f"Number of null values in 'country': {null_count_country}")
print(f"Number of null values in 'year': {null_count_year}")
# Out:
# Number of null values in 'hdi': 8
# Number of null values in 'country': 0
# Number of null values in 'year': 0

# %% [markdown]
# **missing or null values**

# %%
null_percentage = df_filtered.isnull().sum() / df_filtered.shape[0] * 100
null_columns_fill = null_percentage[null_percentage > 10].index

# FILL IF MORE THAN 10%
df_filtered.fillna(df_filtered[null_columns_fill].mean(), inplace=True)

# DROP IF LESS THAN 10
null_columns_drop = null_percentage[null_percentage <= 10].index
df_filtered.dropna(subset=null_columns_drop, inplace=True)

print("\nMissing values after processing:\n", df_filtered.isnull().sum())
# Out:
# Missing values after processing:
#  Unnamed: 0                   0
# iso3                         0
# country                      0
# year                         0
# hdi                          0
# life_expectancy              0
# pop_millions                 0
# hdi_f                        0
# hdi_m                        0
# life_expec_f                 0
# life_expec_m                 0
# expec_yr_school              0
# expec_yr_school_f            0
# expec_yr_school_m            0
# mean_yr_school               0
# mean_yr_school_f             0
# mean_yr_school_m             0
# gross_inc_percap             0
# gross_inc_percap_f           0
# gross_inc_percap_m           0
# gender_development           0
# gender_inequality            0
# secondary_education_f_%      0
# secondary_education_m_%      0
# seats_in_parliament_f_%      0
# seats_in_parliament_m_%      0
# labour_participation_f_%     0
# labour_participation_m_%     0
# co2_emission_tons            0
# ...

# %% [markdown]
# - inconsistent or misspelled country names,
# - duplicate rows,
# - numeric columns stored as text or containing non-numeric symbols

# %%
df_filtered.dtypes
df_filtered.drop_duplicates()
df_filtered.isin(special_symbols).sum()
# Out:
# Unnamed: 0                   0
# iso3                         0
# country                      0
# year                         0
# hdi                          0
# life_expectancy              0
# pop_millions                 0
# hdi_f                        0
# hdi_m                        0
# life_expec_f                 0
# life_expec_m                 0
# expec_yr_school              0
# expec_yr_school_f            0
# expec_yr_school_m            0
# mean_yr_school               0
# mean_yr_school_f             0
# mean_yr_school_m             0
# gross_inc_percap             0
# gross_inc_percap_f           0
# gross_inc_percap_m           0
# gender_development           0
# gender_inequality            0
# secondary_education_f_%      0
# secondary_education_m_%      0
# seats_in_parliament_f_%      0
# seats_in_parliament_m_%      0
# labour_participation_f_%     0
# labour_participation_m_%     0
# co2_emission_tons            0
# mat_footprint_percap_tons    0
# ...

# %% [markdown]
# **Visualization Tasks:**

# %% [markdown]
# **A. Line Chart — HDI Trend (Country-Level):**

# %%
selected_countries = ["Nepal", "India", "Bangladesh", "Bhutan", "Pakistan"]
selected_countries_df = df_filtered[(df_filtered["country"].isin(selected_countries))].copy()


# seperating in terms of year
selected_countries_df_2020 = selected_countries_df[selected_countries_df["year"] == 2020]
selected_countries_df_2021 = selected_countries_df[selected_countries_df["year"] == 2021]
selected_countries_df_2022 = selected_countries_df[selected_countries_df["year"] == 2022]

# %% [markdown]
# - [x]  Plot HDI values for each country across the years 2020, 2021, and 2022

# %%
# Correct HDI Trend Plot (2020–2022)

plt.figure(figsize=(10, 5))

for country in selected_countries:
    country_data = selected_countries_df[selected_countries_df["country"] == country]
    plt.plot(
        country_data["year"],
        country_data["hdi"],
        marker="o",
        label=country
    )

plt.title("HDI Countries (2020–2022)")
plt.xlabel("Year")
plt.ylabel("HDI Score")
plt.xticks([2020, 2021, 2022])
plt.legend(title="Country")



plt.tight_layout()
plt.show()

# %%
# Define regions of interest
regions = [
    "East Asia and the Pacific",
    "Europe and Central Asia",
    "Latin America and the Caribbean",
    "South Asia",
    "Sub-Saharan Africa"
]

# Filter using query and assign region column
region_df = (
    df.query("country in @regions and year in [2020, 2021, 2022]")
      .assign(region=lambda d: d["country"])
)

# Compute average HDI by region and year
avg_hdi = (
    region_df.groupby(["region", "year"], as_index=False)["hdi"]
             .mean()
)

# Plot with seaborn
plt.figure(figsize=(12, 6))
sns.barplot(
    data=avg_hdi,
    x="region",
    y="hdi",
    hue="year"
)

plt.title("Average HDI by Region (2020–2022)")
plt.xlabel("Region")
plt.ylabel("Average HDI")
plt.legend(title="Year")

plt.tight_layout()
plt.show()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Box Plot – HDI Distribution by Year**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16, 5))

axes[0].boxplot(selected_countries_df_2020["hdi"])
axes[0].set_title("HDI Distribution (2020)")
axes[0].set_ylabel("HDI Score")
axes[0].set_xlabel("Selected Countries")

axes[1].boxplot(selected_countries_df_2021["hdi"])
axes[1].set_title("HDI Distribution (2021)")
axes[1].set_ylabel("HDI Score")
axes[1].set_xlabel("Selected Countries")

axes[2].boxplot(selected_countries_df_2022["hdi"])
axes[2].set_title("HDI Distribution (2022)")
axes[2].set_ylabel("HDI Score")
axes[2].set_xlabel("Selected Countries")

fig.text(
    0.5, -0.05,
    "Box plot of HDI across selected countries from 2020 to 2022",
    ha="center",
    fontsize=10
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Scatter Plot – HDI vs. GNI per Capita**

# %%
plt.figure(figsize=(7, 5))
sns.regplot(data=df_filtered, x="gross_inc_percap", y="hdi")

plt.title("HDI vs GNI")
plt.xlabel("GNI per Capita")
plt.ylabel("HDI")

plt.figtext(
    0.5, -0.05,
    "Relationship between HDI vs GNI.",
    ha="center",
    fontsize=10
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Problem 2 – Advanced HDI Exploration**

# %% [markdown]
# **Filtering and Saving Dataset**

# %%
import pandas as pd

south_asia = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# Load dataset
df = pd.read_csv("/content/drive/MyDrive/Copy of Human_Development_Index_Dataset (1).csv", encoding='latin1')

# Filter South Asian countries
df_sa = df[(df['country'].isin(south_asia))].copy()

# Save filtered dataset
df_sa.to_csv("HDI_SouthAsia.csv", index=False)

df_sa
# Out:
#       Unnamed: 0 iso3      country  year    hdi  life_expectancy  \
# 0              1  AFG  Afghanistan  1990  0.284           45.967
# 1              2  AFG  Afghanistan  1991  0.292           46.663
# 2              3  AFG  Afghanistan  1992  0.299           47.596
# 3              4  AFG  Afghanistan  1993  0.307           51.466
# 4              5  AFG  Afghanistan  1994  0.300           51.495
# ...          ...  ...          ...   ...    ...              ...
# 5473        5474  LKA    Sri Lanka  2018  0.774           75.748
# 5474        5475  LKA    Sri Lanka  2019  0.775           76.008
# 5475        5476  LKA    Sri Lanka  2020  0.777           76.393
# 5476        5477  LKA    Sri Lanka  2021  0.783           76.399
# 5477        5478  LKA    Sri Lanka  2022  0.780           76.610
#
#       pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 0        10.694796       NaN       NaN        48.397  ...                 NaN
# ...

# %% [markdown]
# **Create Composite Score & Rank Countries**

# %%
df_sa["Composite Score"] = ( 0.30 * df_sa["life_expectancy"] + 0.30 * df_sa["gross_inc_percap"])

# %% [markdown]
# **Rank South Asian countries based on Composite Score.**

# %%
df_sa.sort_values(by="Composite Score", ascending=False)
# Out:
#       Unnamed: 0 iso3      country  year    hdi  life_expectancy  \
# 3530        3531  MDV     Maldives  2022  0.762           80.839
# 3527        3528  MDV     Maldives  2019  0.753           80.116
# 3526        3527  MDV     Maldives  2018  0.747           80.013
# 3525        3526  MDV     Maldives  2017  0.740           79.943
# 3524        3525  MDV     Maldives  2016  0.734           79.872
# ...          ...  ...          ...   ...    ...              ...
# 8              9  AFG  Afghanistan  1998  0.329           52.943
# 4              5  AFG  Afghanistan  1994  0.300           51.495
# 9             10  AFG  Afghanistan  1999  0.337           54.846
# 10            11  AFG  Afghanistan  2000  0.340           55.298
# 11            12  AFG  Afghanistan  2001  0.344           55.798
#
#       pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_inequality  \
# 3530      0.523787  0.748233  0.767001        81.844  ...              0.328
# ...

# %% [markdown]
# **Horizontal Bar Chart – Top 5 Countries**

# %%
hdi_2022 = df_sa[df_sa["year"] == 2022]

top5_2022 = hdi_2022.sort_values(by="Composite Score", ascending=False).head(5)

top5_2022.plot(
    kind="barh",
    x="country",
    y="Composite Score",
    title="Top 5  Composite Score (2022)",
    figsize=(5,5),
)
# Out:
# <Axes: title={'center': 'Top 5  Composite Score (2022)'}, ylabel='country'>

# %% [markdown]
# **Compare the ranking of countries by Composite Score with their HDI ranking and discuss any
# differences.**

# %%
di_2022 = df_sa[df_sa["year"] == 2022]

top5_2022 = hdi_2022.sort_values(by="hdi", ascending=False).head(5)

top5_2022.plot(
    kind="barh",
    x="country",
    y="hdi",
    title="Top 5  hdi (2022)",
    figsize=(5,5),
)
# Out:
# <Axes: title={'center': 'Top 5  hdi (2022)'}, ylabel='country'>

# %% [markdown]
# **Outlier Detection (1.5 × IQR Rule)**

# %%
def outliers(series):
    """
      parameters: series data
      returns: True if outlier else False
    """
    q1, q3 = series.quantile(0.25), series.quantile(0.75)
    iqr = q3 - q1
    return (series < q1 - 1.5 * iqr) | (series > q3 + 1.5 * iqr)

# %%
df_sa["hdi outlier"] = outliers(df_sa["hdi"])
df_sa["gross_inc_percap outlier"] = outliers(df_sa["gross_inc_percap"])

# %% [markdown]
# **Scatter Plot – Highlight Outliers**

# %%
def outliers(series):
    """
      parameters: series data
      returns: True if outlier else False
    """
    q1, q3 = series.quantile(0.25), series.quantile(0.75)
    iqr = q3 - q1
    return (series < q1 - 1.5 * iqr) | (series > q3 + 1.5 * iqr)

df_sa["hdi outlier"] = outliers(df_sa["hdi"])
df_sa["gross_inc_percap outlier"] = outliers(df_sa["gross_inc_percap"])

df_sa["outlier_type"] = "Normal"

southasia_gni_outlier = df_sa["gross_inc_percap outlier"]
southasia_hdi_outlier = df_sa["hdi outlier"]

df_sa.loc[southasia_gni_outlier, "outlier_type"] = "GDP outlier"
df_sa.loc[southasia_hdi_outlier, "outlier_type"] = "HDI outlier"

palette = {
    "Normal": "blue",
    "GDP outlier": "green",
    "HDI outlier": "orange"
}

plt.figure(figsize=(5,5))
sns.scatterplot(
    data=df_sa,
    x="hdi",
    y="gross_inc_percap",
    hue="outlier_type",
    palette=palette,
    s=70
)

plt.title(" Outliers Highlighted")
plt.xlabel("HDI")
plt.ylabel("Gross Income per Capita")
plt.legend(title="Type")
plt.show()

# %% [markdown]
# **Correlation Calculation**

# %%
corr_genderdevelopment_hdi= df_sa["gender_development"].corr(df_sa["hdi"], method="pearson")
corr_lifeexpectancy_hdi= df_sa["life_expectancy"].corr(df_sa["hdi"], method="pearson")

# %% [markdown]
# **Scatter Plots with Trendlines**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

sns.regplot(
    data=df_sa,
    x="gender_development",
    y="hdi",
    ax=axes[0]
)
axes[0].set_title("Gender Development vs HDI")
axes[0].set_xlabel("Gender Development")
axes[0].set_ylabel("HDI")

sns.regplot(
    data=df_sa,
    x="life_expectancy",
    y="hdi",
    ax=axes[1]
)
axes[1].set_title("Life Expectancy vs HDI")
axes[1].set_xlabel("Life Expectancy")
axes[1].set_ylabel("HDI")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Create GNI–HDI Gap**

# %%
GNI_HDI_Gap = df_sa["gross_inc_percap"] - df_sa["hdi"]
df_sa["GNI HDI Gap"] = GNI_HDI_Gap

# %% [markdown]
# **Rank Countries**

# %%
rank_asc = df_sa.sort_values(by="GNI HDI Gap", ascending=True)
rank_desc = df_sa.sort_values(by="GNI HDI Gap", ascending=False)

# %% [markdown]
# **Plot Top Gaps**

# %%
top3_positive = rank_desc.head(3)
top3_negative = rank_asc.head(3)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

top3_positive.plot(
    kind="barh",
    x="country",
    y="GNI HDI Gap",
    ax=axes[0],
    legend=False
)
axes[0].set_title("Top 3 Positive GNI–HDI Gaps")
axes[0].set_xlabel("GNI–HDI Gap")
axes[0].invert_yaxis()

top3_negative.plot(
    kind="barh",
    x="country",
    y="GNI HDI Gap",
    ax=axes[1],
    legend=False,
    color="red"
)
axes[1].set_title("Top 3 Negative GNI–HDI Gaps")
axes[1].set_xlabel("GNI–HDI Gap")
axes[1].invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Problem 3
# Comparative Regional Analysis: South Asia vs Middle East**

# %% [markdown]
# **Define Country List**

# %%
south_asia_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

middle_east_countries = ["Bahrain", "Iran", "Iraq", "Isreal", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# %% [markdown]
# **Load Dataset & Filter Years**

# %%
df_middle_east_filtered = df_filtered[(df_filtered["country"].isin(middle_east_countries))].copy()
df_southasia_filtered = df_filtered[(df_filtered["country"].isin(south_asia_countries))].copy()

# %% [markdown]
# **Save CSV Files**

# %%
df_southasia_filtered.to_csv("HDI SouthAsia 2020 2022.csv", index=False)
df_middle_east_filtered.to_csv("HDI MiddleEast 2020 2022.csv", index=False)

# %% [markdown]
# **Descriptive Statistics (HDI)**

# %%
mean_middle_east = df_middle_east_filtered["hdi"].mean()
median_middle_east = df_middle_east_filtered["hdi"].median()
std_middle_east = df_middle_east_filtered["hdi"].std()


mean_south_asia = df_southasia_filtered["hdi"].mean()
median_south_asia = df_southasia_filtered["hdi"].median()
std_south_asia = df_southasia_filtered["hdi"].std()


print(f"Mean HDI for Middle East: {mean_middle_east}")
print(f"Median HDI for Middle East: {median_middle_east}")
print(f"Standard Deviation of HDI for Middle East: {std_middle_east}")

print()

print(f"Mean HDI for South Asia: {mean_south_asia}")
print(f"Median HDI for South Asia: {median_south_asia}")
print(f"Standard Deviation of HDI for South Asia: {std_south_asia}")
# Out:
# Mean HDI for Middle East: 0.7767333333333334
# Median HDI for Middle East: 0.8245
# Standard Deviation of HDI for Middle East: 0.1426222242519542
#
# Mean HDI for South Asia: 0.6395833333333333
# Median HDI for South Asia: 0.6505000000000001
# Standard Deviation of HDI for South Asia: 0.09827331747496995

# %% [markdown]
# **Top & Bottom 3 Countries**

# %%
sa_avg_hdi = df_southasia_filtered.groupby("country")["hdi"].mean().sort_values()
me_avg_hdi = df_middle_east_filtered.groupby("country")["hdi"].mean().sort_values()

sa_bottom3 = sa_avg_hdi.head(3)
sa_top3 = sa_avg_hdi.tail(3)

me_bottom3 = me_avg_hdi.head(3)
me_top3 = me_avg_hdi.tail(3)

print("\nSouth Asia Top 3:\n", sa_top3)
print("\nSouth Asia Bottom 3:\n", sa_bottom3)

print("\nMiddle East Top 3:\n", me_top3)
print("\nMiddle East Bottom 3:\n", me_bottom3)
# Out:
# South Asia Top 3:
#  country
# Bhutan       0.677667
# Maldives     0.750667
# Sri Lanka    0.780000
# Name: hdi, dtype: float64
#
# South Asia Bottom 3:
#  country
# Afghanistan    0.474333
# Pakistan       0.537667
# Nepal          0.595000
# Name: hdi, dtype: float64
#
# Middle East Top 3:
#  country
# Saudi Arabia            0.867667
# Bahrain                 0.885333
# United Arab Emirates    0.932667
# Name: hdi, dtype: float64
#
# Middle East Bottom 3:
#  country
# Yemen      0.426333
# Iraq       0.667000
# Lebanon    0.730000
# Name: hdi, dtype: float64

# %% [markdown]
# **Bar Chart Comparison**

# %% [markdown]
# **Create a bar chart comparing these top and bottom performers across the two regions**

# %%
fig, axes = plt.subplots(nrows= 1, ncols = 2, figsize=(10, 5))

sa_bottom3.plot(kind="bar", x="country", y="hdi", ax=axes[0], rot=0, title = "South Asia Bottom 3", color="red")
sa_top3.plot(kind="bar", x="country", y="hdi", ax=axes[1], rot=0, title = "South Asia Top 3")
# Out:
# <Axes: title={'center': 'South Asia Top 3'}, xlabel='country'>

# %%
fig, axes = plt.subplots(nrows= 1, ncols = 2, figsize=(10, 5))

me_bottom3.plot(kind="bar", x="country", y="hdi", ax=axes[0], rot=0, title = "Middle East Bottom 3", color="red")
me_top3.plot(kind="bar", x="country", y="hdi", ax=axes[1], rot=0, title = "Middle East Top 3")
# Out:
# <Axes: title={'center': 'Middle East Top 3'}, xlabel='country'>

# %% [markdown]
# **Metric Comporisons:**

# %%
gender_development_sa = df_southasia_filtered["gender_development"].mean()
life_expectancy_sa = df_southasia_filtered["life_expectancy"].mean()
gross_inc_percap_sa = df_southasia_filtered["gross_inc_percap"].mean()


gender_development_me = df_southasia_filtered["gender_development"].mean()
life_expectancy_me = df_southasia_filtered["life_expectancy"].mean()
gross_inc_percap_me = df_southasia_filtered["gross_inc_percap"].mean()

# %% [markdown]
# **HDI Disparity**

# %%
max_hdi_sa = df_southasia_filtered["hdi"].max()
min_hdi_sa = df_southasia_filtered["hdi"].min()

max_hdi_me = df_middle_east_filtered["hdi"].max()
min_hdi_me = df_middle_east_filtered["hdi"].min()

range_sa = max_hdi_sa - min_hdi_sa
range_me = max_hdi_me - min_hdi_me

print(f"Range of HDI for South Asia: {range_sa}")
print(f"Range of HDI for Middle East: {range_me}")
# Out:
# Range of HDI for South Asia: 0.321
# Range of HDI for Middle East: 0.5130000000000001

# %% [markdown]
# **Compute the coefficient of variation (CV = std/mean) for HDI.**

# %%
std_sa = df_southasia_filtered["hdi"].std()
std_me = df_southasia_filtered["hdi"].std()
mean_sa = df_southasia_filtered["hdi"].mean()
mean_me = df_middle_east_filtered["hdi"].mean()

cv_sa = std_sa / mean_sa
cv_me = std_me / mean_me


print(f"Coefficient of Variation (CV) for South Asia: {cv_sa}")
print(f"Coefficient of Variation (CV) for Middle East: {cv_me}")
# Out:
# Coefficient of Variation (CV) for South Asia: 0.1536520924690084
# Coefficient of Variation (CV) for Middle East: 0.12652130822457722

# %% [markdown]
# **Correlation Analysis**

# %%
# SOUTH ASIA
corr_hdi_gender_sa = df_southasia_filtered["hdi"].corr(df_southasia_filtered["gender_development"], method="pearson")
corr_hdi_life_sa = df_southasia_filtered["hdi"].corr(df_southasia_filtered["life_expectancy"], method="pearson")

# MIDDLE EAST
corr_hdi_gender_me = df_middle_east_filtered["hdi"].corr(df_middle_east_filtered["gender_development"], method="pearson")
corr_hdi_life_me = df_middle_east_filtered["hdi"].corr(df_middle_east_filtered["life_expectancy"], method="pearson")

# %% [markdown]
# **Create scatter plots with trendlines for each correlation.**

# %%
fig, axes = plt.subplots(nrows=1, ncols = 2, figsize= (10,5))

sns.regplot(data = df_southasia_filtered, x="gender_development", y="hdi", ax=axes[0])
axes[0].set_title("South Asia: Gender Development vs HDI")
axes[0].set_xlabel("Gender Development")
axes[0].set_ylabel("HDI")

sns.regplot(data = df_southasia_filtered, x="life_expectancy", y="hdi", ax=axes[1])
axes[1].set_title("South Asia: Life Expectancy vs HDI")
axes[1].set_xlabel("Life Expectancy")
axes[1].set_ylabel("HDI")
# Out:
# Text(0, 0.5, 'HDI')

# %% [markdown]
# **Middle East**

# %%
fig, axes = plt.subplots(nrows=1, ncols = 2, figsize= (10,5))

sns.regplot(data = df_middle_east_filtered, x="gender_development", y="hdi", ax=axes[0])
axes[0].set_title("Middle East: Gender Development vs HDI")
axes[0].set_xlabel("Gender Development")
axes[0].set_ylabel("HDI")

sns.regplot(data = df_middle_east_filtered, x="life_expectancy", y="hdi", ax=axes[1])
axes[1].set_title("Middle East: Life Expectancy vs HDI")
axes[1].set_xlabel("Life Expectancy")
axes[1].set_ylabel("HDI")
# Out:
# Text(0, 0.5, 'HDI')

# %% [markdown]
# **Outlier Detection**

# %%
def outliers(series):
    """
      parameters: series data
      returns: True if outlier else False
    """
    q1, q3 = series.quantile(0.25), series.quantile(0.75)
    iqr = q3 - q1
    return (series < q1 - 1.5 * iqr) | (series > q3 + 1.5 * iqr)

# %%
df_southasia_filtered["HDI Outlier"] = outliers(df_southasia_filtered["hdi"])
df_southasia_filtered["GNI Outlier"] = outliers(df_southasia_filtered["gross_inc_percap"])


df_middle_east_filtered["HDI Outlier"] = outliers(df_middle_east_filtered["hdi"])
df_middle_east_filtered["GNI Outlier"] = outliers(df_middle_east_filtered["gross_inc_percap"])

# %% [markdown]
# **Create scatter plots highlighting outliers in a different color.**

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

# SOUTH ASIA
# NORMAL DATA PLOT ( BOTH OUTLIERS ARE FALSE)
normal_sa = (df_southasia_filtered["HDI Outlier"] == False) & (df_southasia_filtered["GNI Outlier"] == False)
ax[0].scatter(df_southasia_filtered.loc[normal_sa, "hdi"], df_southasia_filtered.loc[normal_sa, "gross_inc_percap"],color="blue", label="Normal")
# HDI OUTLIER
mask_hdi_sa = df_southasia_filtered["HDI Outlier"] == True
ax[0].scatter(df_southasia_filtered.loc[mask_hdi_sa, "hdi"], df_southasia_filtered.loc[mask_hdi_sa, "gross_inc_percap"],color="red", label="HDI Outlier")
# GNI OUTLIER
mask_gni_sa = df_southasia_filtered["GNI Outlier"] == True
ax[0].scatter(df_southasia_filtered.loc[mask_gni_sa, "hdi"],df_southasia_filtered.loc[mask_gni_sa, "gross_inc_percap"],color="green", label="GNI Outlier")


ax[0].set_ylabel("Gross National Income per Capita")
ax[0].set_title("South Asia: HDI vs GNI Outliers")
ax[0].legend()
ax[0].grid(True)

# MIDDLE EAST
# NORMAL DATA PLOT ( BOTH OUTLIERS ARE FALSE)
normal_me = (df_middle_east_filtered["HDI Outlier"] == False) & (df_middle_east_filtered["GNI Outlier"] == False)
ax[1].scatter(df_middle_east_filtered.loc[normal_me, "hdi"],df_middle_east_filtered.loc[normal_me, "gross_inc_percap"],color="blue", label="Normal")
# HDI OUTLIER
mask_hdi_me = df_middle_east_filtered["HDI Outlier"] == True
ax[1].scatter(df_middle_east_filtered.loc[mask_hdi_me, "hdi"],df_middle_east_filtered.loc[mask_hdi_me, "gross_inc_percap"],color="red", label="HDI Outlier")
# GNI OUTLIER
mask_gni_me = df_middle_east_filtered["GNI Outlier"] == True
ax[1].scatter(df_middle_east_filtered.loc[mask_gni_me, "hdi"],df_middle_east_filtered.loc[mask_gni_me, "gross_inc_percap"],color="green", label="GNI Outlier")


ax[1].set_ylabel("Gross National Income per Capita")
ax[1].set_title("Middle East: HDI vs GNI Outliers")
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# Generate a bar plot showing the average HDI by region for the years 2020 to 2022.

# %% [markdown]
# ## Refactor OnrdpuDnU8uF for regional HDI plot
#
# ### Subtask:
# Modify cell OnrdpuDnU8uF to use df_filtered directly for filtering regional data. Since df_filtered already contains data for the years 2020-2022, the explicit year filtering on region_df will be removed, streamlining the code. The country column will be directly assigned to a region column for clarity before grouping, ensuring the NameError is resolved and the code is more robust.

# %% [markdown]
# **Reasoning**:
# The subtask requires modifying the code in cell `OnrdpuDnU8uF` to use the `df_filtered` DataFrame, remove redundant year filtering, and ensure the 'region' column is correctly assigned. This refactors the code to directly address the `NameError` and streamline data processing as instructed.

# %%
regions = [
    'East Asia and the Pacific', 'Europe and Central Asia',
    'Latin America and the Caribbean', 'South Asia',
    'Sub-Saharan Africa']

region_df = df_filtered[df_filtered['country'].isin(regions)].copy()

# The explicit year filtering is removed as df_filtered already contains data for 2020-2022
region_df['region'] = region_df['country']

avg_hdi = region_df.groupby(['region', 'year'])['hdi'].mean().reset_index()
avg_hdi
plt.figure(figsize=(12,6))
sns.barplot(
    data=avg_hdi,
    x='region',
    y='hdi',
    hue='year'

)

plt.title("Average HDI by Region Across 2020 to 2022")
plt.xlabel("Region")
plt.ylabel("Average HDI")
plt.legend(title="Year")
plt.figtext(
    0.5, -0.05,
    "Figure 2: Average Human Development Index (HDI) scores by region for the years 2020, 2021, and 2022.",
    ha="center", fontsize=12
)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# The previous attempt failed with a `NameError` because `df_filtered` was not defined in the execution environment when the cell was run. To fix this, I need to ensure `df_filtered` is created from the globally available `df` DataFrame within the target cell `OnrdpuDnU8uF` before it is used. This makes the cell self-sufficient regarding the `df_filtered` dependency, while also adhering to the instructions to refactor the original code.

# %%
regions = [
    'East Asia and the Pacific', 'Europe and Central Asia',
    'Latin America and the Caribbean', 'South Asia',
    'Sub-Saharan Africa']

# Re-create df_filtered to ensure it's defined in case previous cells were not run
# Assuming 'df' is loaded from a previous cell like x4yBmiP1LX5P
df_filtered = df[df['year'].isin([2020, 2021, 2022])].copy()

region_df = df_filtered[df_filtered['country'].isin(regions)].copy()

# The explicit year filtering `region_df = region_df[region_df['year'].isin([2020, 2021, 2022])]`
# is removed as df_filtered already contains data for 2020-2022.
region_df['region'] = region_df['country']

avg_hdi = region_df.groupby(['region', 'year'])['hdi'].mean().reset_index()
# avg_hdi # Removed for plotting code
plt.figure(figsize=(12,6))
sns.barplot(
    data=avg_hdi,
    x='region',
    y='hdi',
    hue='year'

)

plt.title("Average HDI by Region Across 2020 to 2022")
plt.xlabel("Region")
plt.ylabel("Average HDI")
plt.legend(title="Year")
plt.figtext(
    0.5, -0.05,
    "Figure 2: Average Human Development Index (HDI) scores by region for the years 2020, 2021, and 2022.",
    ha="center", fontsize=12
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Execute OnrdpuDnU8uF
#
# ### Subtask:
# Execute the refactored cell `OnrdpuDnU8uF` to generate the bar plot showing the average HDI by region across 2020 to 2022.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   An initial `NameError` occurred because `df_filtered` was not defined within the scope of the cell's execution.
# *   The `NameError` was resolved by explicitly defining `df_filtered` inside the cell, filtering the main DataFrame `df` for the years 2020, 2021, and 2022.
# *   The modified code successfully generated a bar plot visualizing the average Human Development Index (HDI) by specified regions (East Asia and the Pacific, Europe and Central Asia, Latin America and the Caribbean, South Asia, and Sub-Saharan Africa) for the years 2020 to 2022.
# *   The plot clearly displays the average HDI for each region, with distinct bars representing each year, allowing for a visual comparison of regional HDI scores and their trends over the three-year period.
#
# ### Insights or Next Steps
# *   Ensure all necessary DataFrames and variables are explicitly defined or passed within the scope of the executed cell to prevent runtime errors, especially in environments where cells can be run independently.
# *   Further analysis could involve interpreting the trends shown in the generated bar plot to identify regions with improving or declining HDI, and investigating the factors contributing to these changes.
